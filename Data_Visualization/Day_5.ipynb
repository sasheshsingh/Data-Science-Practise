# %% [markdown]
# # ggplot2

# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
library(dslabs)

# %%
data(murders)

# %%
ls()
# Out:
# [1] "murders"

# %%
p <- ggplot(data = murders)

# %%
p
# Out:
# plot without title

# %%
class(p)
# Out:
# [1] "gg"     "ggplot"

# %%
x = c(1,2,3,4)

# %%
x %>% print()
# Out:
# [1] 1 2 3 4

# %%
data(heights)

# %%
plot1 <- heights %>% ggplot()

# %%
plot2 <- murders %>% ggplot()

# %%
plot1 + geom_point(aes(seq(1, length(height), 1),height)) + geom_text(aes(seq(1, length(height), 1),height,label = height))
# Out:
# plot without title

# %%
plot2 + geom_text(aes(x = population, y = total , label= abb))
# Out:
# plot without title

# %%
plot2 + geom_point(aes(x = population, y = total))
# Out:
# plot without title
