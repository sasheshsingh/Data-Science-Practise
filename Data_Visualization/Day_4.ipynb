# %%
qnorm(0)
# Out:
# [1] -Inf

# %%
qnorm(0.5)
# Out:
# [1] 0

# %%
qnorm(0.4)
# Out:
# [1] -0.2533471

# %%
qnorm(1)
# Out:
# [1] Inf

# %%
qnorm(0.7,69,3)
# Out:
# [1] 70.5732

# %%
pnorm(1)-pnorm(-1)
# Out:
# [1] 0.6826895

# %%
qnorm(0.841344746068543, 69, 3)
# Out:
# [1] 72

# %%
pnorm(2) - pnorm(-2)
# Out:
# [1] 0.9544997

# %%
pnorm(3) - pnorm(-3)
# Out:
# [1] 0.9973002

# %%
pnorm(1)
# Out:
# [1] 0.8413447

# %%
pnorm(2)
# Out:
# [1] 0.9772499

# %%
qnorm(0.025)
# Out:
# [1] -1.959964

# %%
p <- seq(0.01, 0.99, 0.01)
quantiles <- qnorm(p, 69, 3)

# %%
plot(density(quantiles))
# Out:
# Plot with title “density.default(x = quantiles)”

# %%
length(quantiles)
# Out:
# [1] 99

# %%
library(dslabs)

# %%
data(heights)

# %%
x <- heights$height

# %%
avg = mean(x)

# %%
hist(x,breaks=40)
# Out:
# Plot with title “Histogram of x”

# %%
plot(density(x))
# Out:
# Plot with title “density.default(x = x)”

# %%
index <- heights$sex == "Male"

# %%
x <- heights$height[index]

# %%
plot(density(x))
# Out:
# Plot with title “density.default(x = x)”

# %%
len <- seq(0.05, 0.95, 0.05)
observed_values <- quantile(x,len)

# %%
theoretical_values <- qnorm(len, mean(x), sd(x))

# %%
plot(theoretical_values, observed_values)
abline(0,1)
# Out:
# plot without title
